# %% [markdown]
# Reading, Displaying and Saving the Image.

# %%
import cv2
image = cv2.imread('input.jpg')
if image is not None:
    cv2.imshow('Displayed image', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    cv2.imwrite('Output.jpg', image)
    print("Image saved successfully as Output.jpg")
else:
    print('No file named input.jpg found, make sure it is named input.jpg and placed in the current directory before trying again!')
# Out:
# Image saved successfully as Output.jpg

# %% [markdown]
# Resizing Image

# %%
import cv2

image = cv2.imread('input.jpg')

restart_loop = True

while restart_loop:
    print('\nPlease choose the method for resizing the image by entering the corresponding number.\n1. Exact dimensions\n2. Downscale to a percentage of original size\n3. Scale down using INTER_AREA (Best quality for shrinking!)')
    
    # Choice validation
    choice = input('Enter your choice: ').strip()
    
    if not choice.isdigit():
        print('Please enter a valid number!')
        continue
    elif len(choice) > 1:
        print('Please enter only one integer!')
        continue
    
    choice = int(choice)
    restart_loop = False  # Exit main loop if choice is valid

    # Option 1 execution
    if choice == 1:
        restart_loop_2 = True
        while restart_loop_2:
            try:
                print('\nEnter 0 to go back')
                width = int(input('Enter Width: '))
                if width == 0:
                    restart_loop = True  # Send back to main menu
                    restart_loop_2 = False
                    break
                height = int(input('Enter Height: '))
                if height == 0:
                    restart_loop = True  # Send back to main menu
                    restart_loop_2 = False
                    break
                else:
                    res_image = cv2.resize(image, (width, height))
                    restart_loop_2 = False
                    break

            except ValueError:
                print('Please only enter numbers. Example: 400')
                width = None
                height = None
    elif choice == 2:
        restart_loop_3 = True
        while restart_loop_3:
            try:
                print('Enter 0 to go back')
                percentage = int(input('Enter percentage: '))
                if percentage==0:
                    restart_loop = True
                else:
                    number = percentage/100
                    res_image = cv2.resize(image, (0, 0), fx=number, fy=number)
                    restart_loop_3 = False
                    break
            except ValueError:
                print('Please only enter numbers. Example: 50')
                restart_loop_3 = True
    elif choice == 3:
        restart_loop_4 = True
        while restart_loop_4:
                    try:
                        print('\nEnter 0 to go back')
                        width = int(input('Enter Width: '))
                        if width == 0:
                            restart_loop = True  # Send back to main menu
                            restart_loop_2 = False
                            break
                        height = int(input('Enter Height: '))                
                        if height == 0:
                            restart_loop = True  # Send back to main menu
                            restart_loop_4 = False
                            break
                        else:
                            res_image = cv2.resize(image, (400, 300), interpolation=cv2.INTER_AREA)
                            restart_loop_4 = False
                            break
        
                    except ValueError:
                        print('Please only enter numbers. Example: 400')
                        width = None
                        height = None
        




cv2.imshow('Original Image', image)
cv2.imshow('Resized Image', res_image)

cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)

cv2.imwrite("resized_image.jpg", res_image)
print('Image successfully saved as resized_image.jpg')
# Out:
# Please choose the method for resizing the image by entering the corresponding number.
# 1. Exact dimensions
# 2. Downscale to a percentage of original size
# 3. Scale down using INTER_AREA (Best quality for shrinking!)
# Enter 0 to go back
# Image successfully saved as resized_image.jpg

# %% [markdown]
# Flipping images (horizontal, vertical, both)

# %%
import cv2

image = cv2.imread('input.jpg')

flipped_horizontally = cv2.flip(image,  1)
flipped_vertically = cv2.flip(image,  0)
flipped_both = cv2.flip(image,  -1)

cv2.imshow('Original Image', image)
cv2.imshow('Flipped Horizontally', flipped_horizontally)
cv2.imshow('Flipped Vertically', flipped_vertically)
cv2.imshow('Flipped Both Ways', flipped_both)

cv2.waitKey(0)
cv2.destroyAllWindows()
print('Executed Successfully')
# Out:
# Executed Successfully

# %% [markdown]
# Drawing shapes (lines, polygons) and adding text on images

# %%
import cv2

image = cv2.imread('input.jpg')

line = image.copy()
rect = image.copy()

cv2.line(line,(15,15), (475,600),(0,255,0), 2)
cv2.rectangle(rect,(15,15), (475,600),(0,255,0), 2)
cv2.imshow('line',line)
cv2.imshow('rectangle',rect)
cv2.waitKey(0)
cv2.destroyAllWindows()
print('Executed Successfully')
# Out:
# Executed Successfully

# %%
import cv2
img = cv2.imread('input.jpg')
text = input('Enter text: ')

cv2.putText(
    img, text, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2
)

cv2.imshow('Result', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
print('Executed Successfully')
# Out:
# Executed Successfully

# %% [markdown]
# Image translation (shifting) using warpAffine

# %%
import cv2
import numpy as np

img = cv2.imread('input.jpg')
height, width = img.shape[:2]
tx = input('Enter for horizontal')
ty = input("Enter for veritcal")


M = np.float32([
    [1, 0, tx],
    [0, 1, ty]
])

translated_img = cv2.warpAffine(img, M, (width, height))

cv2.imshow('Translated', translated_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
print('Executed Successfully')
# Out:
# Executed Successfully

# %% [markdown]
# Image rotation using getRotationMatrix2D and warpAffine

# %%
import cv2

img = cv2.imread('input.jpg')
height, width = img.shape[:2]

center = (width // 2, height // 2)
angle = 45  # positive = counter-clockwise, negative = clockwise
scale = 1.0

M = cv2.getRotationMatrix2D(center, angle, scale)

rotated_img = cv2.warpAffine(img, M, (width, height))

cv2.imshow('Rotated', rotated_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
print('Executed Successfully')
# Out:
# Executed Successfully

# %% [markdown]
# Thresholding (Binary threshold)

# %%
import cv2

img = cv2.imread('input.jpg', cv2.IMREAD_GRAYSCALE)

thresh_value = 127
max_value = 255

ret, binary_thresh = cv2.threshold(img, thresh_value, max_value, cv2.THRESH_BINARY)

ret, binary_inv_thresh = cv2.threshold(img, thresh_value, max_value, cv2.THRESH_BINARY_INV)

cv2.imshow('Binary', binary_thresh)
cv2.imshow('Binary Inverted', binary_inv_thresh)
cv2.waitKey(0)
cv2.destroyAllWindows()
print('Executed Successfully')
# Out:
# Executed Successfully

# %% [markdown]
# Blurring images using Gaussian Blur and Median Blur

# %%
import cv2

img = cv2.imread('input.jpg')

gaussian_blur = cv2.GaussianBlur(img, (7, 7), 0)

cv2.imshow('Gaussian Blur', gaussian_blur)
cv2.waitKey(0)
cv2.destroyAllWindows()

median_blur = cv2.medianBlur(img, 5)

cv2.imshow('Median Blur', median_blur)
cv2.waitKey(0)
cv2.destroyAllWindows()
print('Executed Successfully')
# Out:
# Executed Successfully

# %% [markdown]
# Morphological operations (Tophat, Blackhat)

# %%
import cv2
import numpy as np

img = cv2.imread('input.jpg', cv2.IMREAD_GRAYSCALE)

kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (15, 15))

tophat = cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernel)

blackhat = cv2.morphologyEx(img, cv2.MORPH_BLACKHAT, kernel)

cv2.imshow('Original', img)
cv2.imshow('Top-Hat (Bright details)', tophat)
cv2.imshow('Black-Hat (Dark details)', blackhat)
cv2.waitKey(0)
cv2.destroyAllWindows()
print('Executed Successfully')
# Out:
# Executed Successfully

# %% [markdown]
# Edge detection using Canny

# %%
import cv2

img = cv2.imread('input.jpg', cv2.IMREAD_GRAYSCALE)

blurred = cv2.GaussianBlur(img, (5, 5), 1.4)

threshold1 = 50 
threshold2 = 150

edges = cv2.Canny(blurred, threshold1, threshold2)

cv2.imshow('Original', img)
cv2.imshow('Canny Edges', edges)
cv2.waitKey(0)
cv2.destroyAllWindows()
print('Executed Successfully')
# Out:
# Executed Successfully

# %% [markdown]
# Reading and writing video files

# %%
import cv2

cap = cv2.VideoCapture('input.mp4')

if not cap.isOpened():
    print("Error opening video file")
    exit()

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output.mp4', fourcc, fps, (width, height))

while cap.isOpened():
    ret, frame = cap.read()
    
    if not ret:
        break
    
    processed_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    processed_frame_bgr = cv2.cvtColor(processed_frame, cv2.COLOR_GRAY2BGR)
    
    out.write(processed_frame_bgr)
    
    cv2.imshow('Video Stream', processed_frame_bgr)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
print('Executed Successfully')
# Out:
# Executed Successfully

# %% [markdown]
# Capturing live video from webcam

# %%
import cv2

cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not access the webcam.")
    exit()

cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)
print('press q to exit')
while True:
    ret, frame = cap.read()
    
    if not ret:
        print("Error: Failed to grab frame.")
        break

    cv2.imshow('Live Webcam Feed', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

print('Executed Successfully')
# Out:
# press q to exit
# Executed Successfully
